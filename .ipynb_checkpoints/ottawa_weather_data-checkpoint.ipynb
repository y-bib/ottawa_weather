# %% [markdown]
# This script downloads weather data from climate.weather.gc.ca and plots for Ottawa (station 4333),
# calculates and plots aggregatet monthly and yearly temparatures,
#
# calculates and plots 1y, 10y rolling temperature means means.
#
# Modify station_id and (optional) year_range for other locations.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
import os

import logging
logging.basicConfig(level=logging.INFO)


# Target download parameters
year_range=range(1889,2025+1)
station_id = 4333
year = 2019
month = 6
format = "csv"  

for year in year_range:
    # Construct the download URL
    try:
        base_url="https://climate.weather.gc.ca/climate_data/bulk_data_e.html"
        params = {
            "format": format,
            "stationID": station_id,
            "Year": year,
            "Month": month,
            "Day": 1,
            "timeframe": 2,
        }
        # Send the request
        response = requests.get(base_url, params=params)
    except requests.exceptions.RequestException as e:
        logging.error(f"Failed for year {year}: {year}")
        continue  
    # Save the CSV file
    output_dir = "weather_data"
    os.makedirs(output_dir, exist_ok=True)
    filename = f"{output_dir}/weather_{station_id}_{year}.csv"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"✅ CSV downloaded to: {filename}")
# Out:
# ✅ CSV downloaded to: weather_data/weather_4333_1889.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1890.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1891.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1892.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1893.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1894.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1895.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1896.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1897.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1898.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1899.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1900.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1901.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1902.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1903.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1904.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1905.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1906.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1907.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1908.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1909.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1910.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1911.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1912.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1913.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1914.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1915.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1916.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1917.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1918.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1919.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1920.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1921.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1922.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1923.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1924.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1925.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1926.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1927.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1928.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1929.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1930.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1931.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1932.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1933.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1934.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1935.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1936.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1937.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1938.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1939.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1940.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1941.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1942.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1943.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1944.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1945.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1946.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1947.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1948.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1949.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1950.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1951.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1952.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1953.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1954.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1955.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1956.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1957.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1958.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1959.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1960.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1961.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1962.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1963.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1964.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1965.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1966.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1967.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1968.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1969.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1970.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1971.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1972.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1973.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1974.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1975.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1976.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1977.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1978.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1979.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1980.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1981.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1982.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1983.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1984.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1985.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1986.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1987.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1988.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1989.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1990.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1991.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1992.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1993.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1994.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1995.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1996.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1997.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1998.csv
# ✅ CSV downloaded to: weather_data/weather_4333_1999.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2000.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2001.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2002.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2003.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2004.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2005.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2006.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2007.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2008.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2009.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2010.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2011.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2012.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2013.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2014.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2015.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2016.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2017.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2018.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2019.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2020.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2021.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2022.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2023.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2024.csv
# ✅ CSV downloaded to: weather_data/weather_4333_2025.csv

# %%
df = pd.DataFrame()

#station_id = 4333
for year in year_range:
    filename = f"{output_dir}/weather_{station_id}_{year}.csv"
    df_add = pd.read_csv(filename,sep=',')
    df=pd.concat([df, df_add], ignore_index=True)
    print(f"✅ CSV {filename} added to dataframe")
# Out:
# ✅ CSV weather_data/weather_4333_1889.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1890.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1891.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1892.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1893.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1894.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1895.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1896.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1897.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1898.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1899.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1900.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1901.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1902.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1903.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1904.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1905.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1906.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1907.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1908.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1909.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1910.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1911.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1912.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1913.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1914.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1915.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1916.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1917.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1918.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1919.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1920.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1921.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1922.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1923.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1924.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1925.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1926.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1927.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1928.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1929.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1930.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1931.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1932.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1933.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1934.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1935.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1936.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1937.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1938.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1939.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1940.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1941.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1942.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1943.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1944.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1945.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1946.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1947.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1948.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1949.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1950.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1951.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1952.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1953.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1954.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1955.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1956.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1957.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1958.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1959.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1960.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1961.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1962.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1963.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1964.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1965.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1966.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1967.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1968.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1969.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1970.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1971.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1972.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1973.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1974.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1975.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1976.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1977.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1978.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1979.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1980.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1981.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1982.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1983.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1984.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1985.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1986.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1987.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1988.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1989.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1990.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1991.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1992.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1993.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1994.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1995.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1996.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1997.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1998.csv added to dataframe
# ✅ CSV weather_data/weather_4333_1999.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2000.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2001.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2002.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2003.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2004.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2005.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2006.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2007.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2008.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2009.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2010.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2011.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2012.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2013.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2014.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2015.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2016.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2017.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2018.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2019.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2020.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2021.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2022.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2023.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2024.csv added to dataframe
# ✅ CSV weather_data/weather_4333_2025.csv added to dataframe

# %%
df.columns
# Out:
# Index(['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID',
#        'Date/Time', 'Year', 'Month', 'Day', 'Data Quality', 'Max Temp (°C)',
#        'Max Temp Flag', 'Min Temp (°C)', 'Min Temp Flag', 'Mean Temp (°C)',
#        'Mean Temp Flag', 'Heat Deg Days (°C)', 'Heat Deg Days Flag',
#        'Cool Deg Days (°C)', 'Cool Deg Days Flag', 'Total Rain (mm)',
#        'Total Rain Flag', 'Total Snow (cm)', 'Total Snow Flag',
#        'Total Precip (mm)', 'Total Precip Flag', 'Snow on Grnd (cm)',
#        'Snow on Grnd Flag', 'Dir of Max Gust (10s deg)',
#        'Dir of Max Gust Flag', 'Spd of Max Gust (km/h)',
#        'Spd of Max Gust Flag'],
#       dtype='object')

# %%
df.loc[:,['Year', 'Month', 'Day','Max Temp (°C)','Min Temp (°C)','Mean Temp (°C)','Total Rain (mm)','Total Snow (cm)','Total Precip (mm)']]
# Out:
#        Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0      1889      1    1            NaN            NaN             NaN
# 1      1889      1    2            NaN            NaN             NaN
# 2      1889      1    3            NaN            NaN             NaN
# 3      1889      1    4            NaN            NaN             NaN
# 4      1889      1    5            NaN            NaN             NaN
# ...     ...    ...  ...            ...            ...             ...
# 50033  2025     12   27            NaN            NaN             NaN
# 50034  2025     12   28            NaN            NaN             NaN
# 50035  2025     12   29            NaN            NaN             NaN
# 50036  2025     12   30            NaN            NaN             NaN
# 50037  2025     12   31            NaN            NaN             NaN
#
#        Total Rain (mm)  Total Snow (cm)  Total Precip (mm)
# 0                  NaN              NaN                NaN
# 1                  NaN              NaN                NaN
# 2                  NaN              NaN                NaN
# 3                  NaN              NaN                NaN
# 4                  NaN              NaN                NaN
# ...                ...              ...                ...
# 50033              NaN              NaN                NaN
# 50034              NaN              NaN                NaN
# 50035              NaN              NaN                NaN
# 50036              NaN              NaN                NaN
# 50037              NaN              NaN                NaN
#
# [50038 rows x 9 columns]

# %%
col_names=['Year', 'Month', 'Day','Max Temp (°C)','Min Temp (°C)','Mean Temp (°C)','Total Rain (mm)','Total Snow (cm)','Total Precip (mm)']

# %%
df_current = df.dropna(subset=col_names)[col_names].copy()

# %%
print(df_current.shape)      # (number_of_rows, number_of_columns)
print(len(df_current.index)) # should match number_of_rows
print(df_current.head())     # inspect actual rows
# Out:
# (49322, 9)
# 49322
#      Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 304  1889     11    1            3.9           -1.7             1.1
# 305  1889     11    2           12.2            0.6             6.4
# 306  1889     11    3           14.4            4.4             9.4
# 307  1889     11    4            8.3            1.7             5.0
# 308  1889     11    5            2.8           -0.6             1.1
#
#      Total Rain (mm)  Total Snow (cm)  Total Precip (mm)
# 304              0.0              0.0                0.0
# 305              0.0              0.0                0.0
# 306              5.6              0.0                5.6
# 307              0.0              0.0                0.0
# 308              0.0              0.0                0.0

# %%
df_current
# Out:
#        Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 304    1889     11    1            3.9           -1.7             1.1
# 305    1889     11    2           12.2            0.6             6.4
# 306    1889     11    3           14.4            4.4             9.4
# 307    1889     11    4            8.3            1.7             5.0
# 308    1889     11    5            2.8           -0.6             1.1
# ...     ...    ...  ...            ...            ...             ...
# 49807  2025      5   15           23.5           16.5            20.0
# 49808  2025      5   16           28.0           12.5            20.3
# 49809  2025      5   17           22.5           15.0            18.8
# 49810  2025      5   18           17.0           10.0            13.5
# 49811  2025      5   19           13.0            5.0             9.0
#
#        Total Rain (mm)  Total Snow (cm)  Total Precip (mm)
# 304                0.0              0.0                0.0
# 305                0.0              0.0                0.0
# 306                5.6              0.0                5.6
# 307                0.0              0.0                0.0
# 308                0.0              0.0                0.0
# ...                ...              ...                ...
# 49807              0.0              0.0                0.0
# 49808              0.0              0.0                0.0
# 49809              8.0              0.0                8.0
# 49810              0.6              0.0                0.6
# 49811              0.0              0.0                0.0
#
# [49322 rows x 9 columns]

# %%
df_agg_month=df_current.groupby(["Year", "Month"], as_index=False).agg({
    'Max Temp (°C)': 'max',
    'Min Temp (°C)': 'min', 
    'Mean Temp (°C)': 'mean',
    'Total Rain (mm)': 'mean',
    'Total Snow (cm)': 'mean',
    'Total Precip (mm)': 'mean'
})
df_agg_month
# Out:
#       Year  Month  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0     1889     11           14.4          -11.7        1.186667
# 1     1889     12            5.6          -23.3       -5.629032
# 2     1890      1            8.9          -28.9       -9.877419
# 3     1890      2            7.2          -24.4       -8.803571
# 4     1890      3            6.1          -23.3       -4.854839
# ...    ...    ...            ...            ...             ...
# 1620  2025      1            2.5          -21.0       -8.141935
# 1621  2025      2            6.0          -23.0       -9.160000
# 1622  2025      3           17.0          -23.5       -0.119355
# 1623  2025      4           25.0           -9.0        6.113333
# 1624  2025      5           28.0            0.0       14.694737
#
#       Total Rain (mm)  Total Snow (cm)  Total Precip (mm)
# 0            1.650000         0.676667           2.326667
# 1            1.600000         0.606452           2.206452
# 2            1.432258         1.758065           3.190323
# 3            1.725000         1.782143           3.507143
# 4            0.609677         0.687097           1.293548
# ...               ...              ...                ...
# 1620         0.167742         0.935484           0.845161
# 1621         0.040000         3.080000           2.304000
# 1622         0.864516         1.032258           1.774194
# 1623         2.433333         0.433333           2.766667
# 1624         1.494737         0.000000           1.494737
#
# [1625 rows x 8 columns]

# %%
# Plot all available daily mean temp values
ax = sns.lineplot(data=df_agg_month, x=df_agg_month.index, y='Mean Temp (°C)')

unique_years = df_agg_month['Year'].drop_duplicates()
years_to_show = unique_years[unique_years % 20 == 0].drop_duplicates()
tick_positions = years_to_show.index

# Set x-ticks and labels
ax.set_xticks(tick_positions)
ax.set_xticklabels(years_to_show.tolist(), rotation=0)

# Decorate the plot
plt.title('Month Mean Temperature Trend')
plt.xlabel('Year')
plt.ylabel('Mean Month Temp (°C)')
#splt.grid(True)
#plt.tight_layout()
plt.show()

# %%
ax=sns.lineplot(data=df_agg_month, x=df_agg_month.index, y='Mean Temp (°C)')

unique_years = df_agg_month['Year'].drop_duplicates()
years_to_show = unique_years[unique_years % 20 == 0].drop_duplicates()
tick_positions = years_to_show.index

# Set x-ticks and labels
ax.set_xticks(tick_positions)
ax.set_xticklabels(years_to_show.tolist(), rotation=0)

plt.title('Month Mean Temperature Trend')
plt.ylabel('Meam Month Temp (°C)')
plt.xlabel("Year")
plt.show()

# %%
df_year=df_current.groupby("Year").agg({
    'Max Temp (°C)': 'max',
    'Min Temp (°C)': 'min', 
    'Mean Temp (°C)': 'mean',
    'Total Rain (mm)': 'mean',
    'Total Snow (cm)': 'mean',
    'Total Precip (mm)': 'mean'
}).iloc[1:-1]
df_year
# Out:
#       Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Total Rain (mm)  \
# Year
# 1890           33.9          -28.9        4.707143         1.762912
# 1891           33.9          -32.8        6.194521         2.115342
# 1892           36.1          -31.1        5.110109         1.603279
# 1893           35.0          -32.2        4.354521         2.304658
# 1894           33.9          -32.2        6.108493         1.653151
# ...             ...            ...             ...              ...
# 2020           37.0          -26.5        8.595286         2.176431
# 2021           33.5          -23.0        8.392055         2.030959
# 2022           33.0          -26.5        8.816082         2.567251
# 2023           34.5          -33.0        8.558791         2.476099
# 2024           32.5          -18.5        9.169382         2.184270
#
#       Total Snow (cm)  Total Precip (mm)
# Year
# 1890         0.510714           2.273352
# 1891         0.521370           2.636986
# 1892         0.756011           2.359290
# 1893         0.788767           3.093151
# 1894         0.486575           2.139726
# ...               ...                ...
# 2020         0.540741           2.641751
# 2021         0.471233           2.458356
# 2022         0.447368           2.963743
# 2023         0.601648           2.998626
# 2024         0.469101           2.563483
#
# [135 rows x 6 columns]

# %%
sns.lineplot(data=df_year, x=df_year.index, y='Max Temp (°C)')
sns.lineplot(data=df_year, x=df_year.index, y='Min Temp (°C)')
sns.lineplot(data=df_year, x=df_year.index, y='Mean Temp (°C)')
plt.title('Year Min and Max Temperature')
plt.ylabel('Extreme and Average Year Temp (°C)')
plt.xlabel("Year")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

x = df_year.index.to_numpy().reshape(-1, 1)
y = df_year['Mean Temp (°C)']  
model = LinearRegression()
model.fit(x, y)

plt.scatter(x, y, color='blue', label='Actual Data Points')
plt.plot(x, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel('Year')
plt.ylabel('Mean Temp (°C)')
plt.title('Linear Regression Results')

plt.legend()
plt.grid(True)
plt.show()

# Make predictions and plot - works better for multidimension free variable
# y_pred = model.predict(x)
# sns.scatterplot(x=df_year['Mean Temp (°C)'], y=y_pred, color='blue', label='Predicted vs Actual Mean Temp')
# sns.lineplot(x=df_year['Mean Temp (°C)'], y=df_year['Mean Temp (°C)'], color='red', label='Perfect Prediction')

# plt.xlabel('Actual Target')
# plt.ylabel('Predicted Target')
# plt.title('Actual vs Predicted Values')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# View coefficients
# print("Slope:", model.coef_)
# print("Intercept:", model.intercept_)

# %%
# Forecast of dayly mean temperature using using PyTorch and LSTM (Long Short-Term Memory)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# LINEAR REGRESSION


# x = torch.tensor(df_current[['Year', 'Month', 'Day']].to_numpy(), dtype=torch.float32)
# y = torch.tensor(df_current[['Mean Temp (°C)']].to_numpy(), dtype=torch.float32)
# model = nn.Linear(in_features=3, out_features=1)

# criterion = nn.MSELoss()
# optimizer = optim.SGD(model.parameters(), lr=0.01)

# for i in range(60):
#     y_pred = model(x)
#     loss = criterion(y_pred, y)
#     optimizer.zero_grad()
#     loss.backward()
#     torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#     optimizer.step()

# # Print learned parameters
# print("Learned weights:", model.weight.data)
# print("Learned bias:", model.bias.data)

# After training loop
# y_pred = model(x).detach().numpy()
# y_actual = y.numpy()

# # Plot actual vs predicted
# plt.figure(figsize=(8, 5))
# plt.scatter(y_actual, y_pred, color='blue', label='Predicted vs Actual')
# plt.plot(y_actual, y_actual, color='red', label='Perfect Prediction Line')

# plt.xlabel('Actual Mean Temp (°C)')
# plt.ylabel('Predicted Mean Temp (°C)')
# plt.title('Actual vs Predicted Temperatures')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()
# Out:
# Learned weights: tensor([[0.0043, 0.4426, 0.2879]])
# Learned bias: tensor([0.4287])

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Combine date features into a single time index (optional)
df_current['Date'] = pd.to_datetime(df_current[1:3000][['Year', 'Month', 'Day']])
df_current.sort_values('Date', inplace=True)

# Select target column
target = df_current[1:3000]['Mean Temp (°C)'].values.reshape(-1, 1)

# Normalize target values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = scaler.fit_transform(target)

# %%
sequence_length = 30
X, y = [], []

for i in range(len(scaled_target) - sequence_length):
    X.append(scaled_target[i:i + sequence_length])
    y.append(scaled_target[i + sequence_length])

X = np.array(X)
y = np.array(y)

# Convert to tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.2):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.linear(out[:, -1, :])

# %%
from torch.utils.data import DataLoader, TensorDataset

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(input_size=1, hidden_size=128, num_layers=2, output_size=1).to(device)
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=32)

for epoch in range(50):
    model.train()
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        loss = loss_fn(model(batch_X), batch_y)
        loss.backward()
        optimizer.step()

# %%
split = int(len(X_tensor) * 0.8)
X_train, X_test = X_tensor[:split], X_tensor[split:]
y_train, y_test = y_tensor[:split], y_tensor[split:]

# %%
# Switch to evaluation mode
model.eval()

# Collect predictions
predictions = []
actuals = []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X = batch_X.to(device)
        output = model(batch_X)
        predictions.extend(output.cpu().numpy())
        actuals.extend(batch_y.cpu().numpy())

# Convert to NumPy arrays
predictions = np.array(predictions)
actuals = np.array(actuals)

# Inverse transform to original scale (if you used MinMaxScaler)
predictions = scaler.inverse_transform(predictions)
actuals = scaler.inverse_transform(actuals)

# Plot
plt.figure(figsize=(10, 5))
# plt.plot(actuals, label="Actual", color='blue')
# plt.plot(predictions, label="Predicted", color='orange')
date_axis = df_current['Date'].values[3000-len(actuals):3000]
plt.plot(date_axis, actuals, label="Actual")
plt.plot(date_axis, predictions, label="Predicted")
plt.title("LSTM Forecast: Actual vs Predicted")
plt.xlabel("Time Step")
plt.ylabel("Mean Temp (°C)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Rolling minimum and mean temperatures

# %%
# Plot raw daily minimum temperature

# Plot 30-day rolling average
df_current.loc[:, 'Min Temp (°C)'].rolling(window=365).mean().plot(
    lw=2, color='blue', label='365-day Rolling Mean'
)

# Plot 365-day rolling average
ax=df_current.loc[:, 'Min Temp (°C)'].rolling(window=3650).mean().plot(
    lw=2, color='red', label='3650-day Rolling Mean'
)
unique_years = df_current['Year'].drop_duplicates()
years_to_show = unique_years[unique_years % 20 == 0].drop_duplicates()
tick_positions = years_to_show.index

# Set x-ticks and labels
ax.set_xticks(tick_positions)
ax.set_xticklabels(years_to_show.tolist(), rotation=0)

# Beautify the plot
plt.title("Smoothed Yearly vs 10-Yearly Min Temperature")
plt.ylabel("Temperature (°C)")
plt.xlabel("Index (Days)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot raw daily minimum temperature
#df_current.loc[:365*8, 'Min Temp (°C)'].plot(label='Daily Min Temp', alpha=0.6)

# Plot 30-day rolling average
ax=df_current.loc[:, 'Mean Temp (°C)'].rolling(window=7300).mean().plot(
    lw=2, color='red', label='7300-day Rolling Mean'
)
unique_years = df_current['Year'].drop_duplicates()
years_to_show = unique_years[unique_years % 20 == 0].drop_duplicates()
tick_positions = years_to_show.index

# Set x-ticks and labels
ax.set_xticks(tick_positions)
ax.set_xticklabels(years_to_show.tolist(), rotation=0)


# Beautify the plot
plt.title("Smoothed 10-Yearly Mean Temperature")
plt.ylabel("Temperature (°C)")
plt.xlabel("Date")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
